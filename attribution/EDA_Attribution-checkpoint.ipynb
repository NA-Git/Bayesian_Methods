# %% [markdown]
# #### The purpose of this EDA notebook is the following:
# - Better understand the nature of the relationship between the independent variables
# - Create an initial model with reasonable economic assumptions that may be dropped in later versions
# - Explore methods of imputation for missing variables to provide more data samples
# - Avoid linear combinations that might be more difficult to spot in the Bayesian Modeling process
# - Establish a reasonable measure of variable importance, which along with correlation plots may inform initial hierarchies
# - Create visualizations of poor quality data and also establish probability distributions for the likelihood function

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# sns.set_style('darkgrid')
from rfpimp import *
from rfpimp import plot_corr_heatmap
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.inspection import permutation_importance
import category_encoders as ce

# %% [markdown]
# #### In an effort to generalize for future EDA, 'df' makes it easier to debug

# %%
df = pd.read_csv('C:/Users/norri/Desktop/cortex_Push.csv')
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54039 entries, 0 to 54038
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ClientId                                      54039 non-null  int64
#  1   Program Id                                    54039 non-null  int64
#  2   Program Name                                  54039 non-null  object
#  3   Retailers                                     54039 non-null  object
#  4   TacticId                                      54039 non-null  int64
#  5   Tactic                                        54039 non-null  object
#  6   CategoryId                                    54039 non-null  int64
#  7   Tactic Category                               54039 non-null  object
#  8   VendorId                                      53135 non-null  float64
#  9   Vendor                                        54039 non-null  object
#  10  Total Impressions for Tactic                  54039 non-null  int64
#  11  Total Tactic Spend                            54039 non-null  float64
#  12  Total Tactic Insertion Cost                   54039 non-null  float64
#  13  Total Tactic Redemption Cost                  54039 non-null  float64
#  14  Tactic Start Date                             54039 non-null  object
#  15  Tactic End Date                               54039 non-null  object
#  16  BrandId                                       54039 non-null  int64
#  17  Brand                                         54039 non-null  object
#  18  Nielsen_Week_Year                             54039 non-null  int64
#  19  StoreCount                                    54031 non-null  float64
#  20  RMN                                           54039 non-null  object
#  21  Weeks                                         54039 non-null  int64
#  22  Impressions per Week                          54039 non-null  float64
#  23  Brand Share of Program Budget                 54039 non-null  float64
#  24  Brand Share of Total Tactic Spend             54039 non-null  float64
#  25  Brand Share of Tactic Insertion Cost          54039 non-null  float64
#  26  Brand Share of Tactic Redemption Cost         54039 non-null  float64
#  27  Weekly Brand Share of Total Tactic Spend      54039 non-null  float64
#  28  Weekly Brand Share of Tactic Insertion Cost   54039 non-null  float64
#  29  Weekly Brand Share of Tactic Redemption Cost  54039 non-null  float64
#  30  Total Sales                                   20515 non-null  float64
#  31  Base $                                        20515 non-null  float64
#  32  Incr $                                        20515 non-null  float64
#  33  Units                                         20515 non-null  float64
#  34  Base Units                                    20515 non-null  float64
#  35  Incr Units                                    20515 non-null  float64
#  36  Avg Unit Price                                20523 non-null  float64
#  37  Any Promo Units                               20523 non-null  float64
#  38  %ACV Distribution                             20481 non-null  float64
#  39  Any Promo %ACV                                20481 non-null  float64
#  40  Disp w/o Feat %ACV                            20481 non-null  float64
#  41  Feat & Disp %ACV                              20481 non-null  float64
#  42  Feat w/o Disp %ACV                            20481 non-null  float64
#  43  Price Decr Only %ACV                          20481 non-null  float64
#  44  Number of UPCs Selling                        20523 non-null  float64
#  45  $ Shr - Ty Subcategory                        5220 non-null   float64
#  46  Units Shr - Ty Category                       3153 non-null   float64
#  47  Units Shr - Ty Subcategory                    5220 non-null   float64
# dtypes: float64(31), int64(8), object(9)
# memory usage: 19.8+ MB

# %% [markdown]
# ### The info function above tells us we have three data types and counts of each. The next section will explore those variables in groups.

# %%
segment = [var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(segment)))
print('The categorical variables are :\n\n', segment)
print(df[segment].isnull().sum() + df[segment].isna().sum())
df_cat = df.select_dtypes(include=object)
unique_cats = df_cat.nunique()

# I like this visualization but it needs some tweaking or replacement
# note: write a function because this repetitive plotting could be done in a few lines
for col in segment:
    sns.boxplot(y=df_cat.nunique().astype('int32'), x=col, data=df_cat)
    plt.show()
# Out:
# There are 9 categorical variables
#
# The categorical variables are :
#
#  ['Program Name', 'Retailers', 'Tactic', 'Tactic Category', 'Vendor', 'Tactic Start Date', 'Tactic End Date', 'Brand', 'RMN']
# Program Name         0
# Retailers            0
# Tactic               0
# Tactic Category      0
# Vendor               0
# Tactic Start Date    0
# Tactic End Date      0
# Brand                0
# RMN                  0
# dtype: int64

# %%
integer = [var for var in df.columns if df[var].dtype=='int64']
print('There are {} integer variables\n'.format(len(integer)))
print('The integer variables are :\n\n', integer)
print(df[integer].isnull().sum())
# Out:
# There are 8 integer variables
#
# The integer variables are :
#
#  ['ClientId', 'Program Id', 'TacticId', 'CategoryId', 'Total Impressions for Tactic', 'BrandId', 'Nielsen_Week_Year', 'Weeks']
# ClientId                        0
# Program Id                      0
# TacticId                        0
# CategoryId                      0
# Total Impressions for Tactic    0
# BrandId                         0
# Nielsen_Week_Year               0
# Weeks                           0
# dtype: int64

# %%
fp = [var for var in df.columns if df[var].dtype=='float64']
print('There are {} float variables\n'.format(len(fp)))
print('The float variables are :\n\n', fp)
print(df[fp].isnull().sum() + df[fp].isna().sum())
# Out:
# There are 31 float variables
#
# The float variables are :
#
#  ['VendorId', 'Total Tactic Spend', 'Total Tactic Insertion Cost', 'Total Tactic Redemption Cost', 'StoreCount', 'Impressions per Week', 'Brand Share of Program Budget', 'Brand Share of Total Tactic Spend', 'Brand Share of Tactic Insertion Cost', 'Brand Share of Tactic Redemption Cost', 'Weekly Brand Share of Total Tactic Spend', 'Weekly Brand Share of Tactic Insertion Cost', 'Weekly Brand Share of Tactic Redemption Cost', 'Total Sales', 'Base $', 'Incr $', 'Units', 'Base Units', 'Incr Units', 'Avg Unit Price', 'Any Promo Units', '%ACV Distribution', 'Any Promo %ACV', 'Disp w/o Feat %ACV', 'Feat & Disp %ACV', 'Feat w/o Disp %ACV', 'Price Decr Only %ACV', 'Number of UPCs Selling', '$ Shr - Ty Subcategory', 'Units Shr - Ty Category', 'Units Shr - Ty Subcategory']
# VendorId                                          1808
# Total Tactic Spend                                   0
# Total Tactic Insertion Cost                          0
# Total Tactic Redemption Cost                         0
# StoreCount                                          16
# Impressions per Week                                 0
# Brand Share of Program Budget                        0
# Brand Share of Total Tactic Spend                    0
# Brand Share of Tactic Insertion Cost                 0
# Brand Share of Tactic Redemption Cost                0
# Weekly Brand Share of Total Tactic Spend             0
# Weekly Brand Share of Tactic Insertion Cost          0
# Weekly Brand Share of Tactic Redemption Cost         0
# Total Sales                                      67048
# Base $                                           67048
# Incr $                                           67048
# Units                                            67048
# Base Units                                       67048
# Incr Units                                       67048
# Avg Unit Price                                   67032
# Any Promo Units                                  67032
# %ACV Distribution                                67116
# Any Promo %ACV                                   67116
# Disp w/o Feat %ACV                               67116
# Feat & Disp %ACV                                 67116
# Feat w/o Disp %ACV                               67116
# Price Decr Only %ACV                             67116
# Number of UPCs Selling                           67032
# $ Shr - Ty Subcategory                           97638
# Units Shr - Ty Category                         101772
# Units Shr - Ty Subcategory                       97638
# dtype: int64

# %% [markdown]
# ### Clearly the float variables contain all the missing data in the dataset. In
# ### cases like this, dropping the missing values are a trade-off to consider
# ### against dropping an entire column and losing its input into the model

# %%
# in addition to the kde plots at the bottom of the notebook, this give some
# idea as to the distributions for the likelihood functions
df.hist(figsize=(25, 25), bins=20)
plt.show()

# %%
missing_segment = (df[segment].isnull().sum() / len(df)) * 100
missing_integer = (df[integer].isnull().sum() / len(df)) * 100
missing_float = (df[fp].isnull().sum() / len(df)) * 100
print(missing_segment)
print(missing_integer)
print(missing_float)
# Out:
# Program Name         0.0
# Retailers            0.0
# Tactic               0.0
# Tactic Category      0.0
# Vendor               0.0
# Tactic Start Date    0.0
# Tactic End Date      0.0
# Brand                0.0
# RMN                  0.0
# dtype: float64
# ClientId                        0.0
# Program Id                      0.0
# TacticId                        0.0
# CategoryId                      0.0
# Total Impressions for Tactic    0.0
# BrandId                         0.0
# Nielsen_Week_Year               0.0
# Weeks                           0.0
# dtype: float64
# VendorId                                         1.672866
# Total Tactic Spend                               0.000000
# Total Tactic Insertion Cost                      0.000000
# Total Tactic Redemption Cost                     0.000000
# StoreCount                                       0.014804
# Impressions per Week                             0.000000
# Brand Share of Program Budget                    0.000000
# Brand Share of Total Tactic Spend                0.000000
# Brand Share of Tactic Insertion Cost             0.000000
# Brand Share of Tactic Redemption Cost            0.000000
# Weekly Brand Share of Total Tactic Spend         0.000000
# Weekly Brand Share of Tactic Insertion Cost      0.000000
# Weekly Brand Share of Tactic Redemption Cost     0.000000
# Total Sales                                     62.036677
# Base $                                          62.036677
# Incr $                                          62.036677
# Units                                           62.036677
# Base Units                                      62.036677
# Incr Units                                      62.036677
# Avg Unit Price                                  62.021873
# Any Promo Units                                 62.021873
# %ACV Distribution                               62.099595
# Any Promo %ACV                                  62.099595
# Disp w/o Feat %ACV                              62.099595
# Feat & Disp %ACV                                62.099595
# Feat w/o Disp %ACV                              62.099595
# Price Decr Only %ACV                            62.099595
# Number of UPCs Selling                          62.021873
# $ Shr - Ty Subcategory                          90.340310
# Units Shr - Ty Category                         94.165325
# Units Shr - Ty Subcategory                      90.340310
# dtype: float64

# %%
print('Missing variables check' + ' ' + str((len(integer) + len(fp) +
                                             len(segment) - len(df.T))))
print(df.info())
print(df.describe())
# Out:
# Missing variables check 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54039 entries, 0 to 54038
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ClientId                                      54039 non-null  int64
#  1   Program Id                                    54039 non-null  int64
#  2   Program Name                                  54039 non-null  object
#  3   Retailers                                     54039 non-null  object
#  4   TacticId                                      54039 non-null  int64
#  5   Tactic                                        54039 non-null  object
#  6   CategoryId                                    54039 non-null  int64
#  7   Tactic Category                               54039 non-null  object
#  8   VendorId                                      53135 non-null  float64
#  9   Vendor                                        54039 non-null  object
#  10  Total Impressions for Tactic                  54039 non-null  int64
#  11  Total Tactic Spend                            54039 non-null  float64
#  12  Total Tactic Insertion Cost                   54039 non-null  float64
#  13  Total Tactic Redemption Cost                  54039 non-null  float64
#  14  Tactic Start Date                             54039 non-null  object
#  15  Tactic End Date                               54039 non-null  object
#  16  BrandId                                       54039 non-null  int64
#  17  Brand                                         54039 non-null  object
#  18  Nielsen_Week_Year                             54039 non-null  int64
#  19  StoreCount                                    54031 non-null  float64
#  20  RMN                                           54039 non-null  object
#  21  Weeks                                         54039 non-null  int64
#  22  Impressions per Week                          54039 non-null  float64
#  23  Brand Share of Program Budget                 54039 non-null  float64
#  24  Brand Share of Total Tactic Spend             54039 non-null  float64
#  25  Brand Share of Tactic Insertion Cost          54039 non-null  float64
#  26  Brand Share of Tactic Redemption Cost         54039 non-null  float64
#  27  Weekly Brand Share of Total Tactic Spend      54039 non-null  float64
#  28  Weekly Brand Share of Tactic Insertion Cost   54039 non-null  float64
#  29  Weekly Brand Share of Tactic Redemption Cost  54039 non-null  float64
#  30  Total Sales                                   20515 non-null  float64
#  31  Base $                                        20515 non-null  float64
#  32  Incr $                                        20515 non-null  float64
#  33  Units                                         20515 non-null  float64
#  34  Base Units                                    20515 non-null  float64
#  35  Incr Units                                    20515 non-null  float64
#  36  Avg Unit Price                                20523 non-null  float64
#  37  Any Promo Units                               20523 non-null  float64
#  38  %ACV Distribution                             20481 non-null  float64
#  39  Any Promo %ACV                                20481 non-null  float64
#  40  Disp w/o Feat %ACV                            20481 non-null  float64
#  41  Feat & Disp %ACV                              20481 non-null  float64
#  42  Feat w/o Disp %ACV                            20481 non-null  float64
#  43  Price Decr Only %ACV                          20481 non-null  float64
#  44  Number of UPCs Selling                        20523 non-null  float64
#  45  $ Shr - Ty Subcategory                        5220 non-null   float64
#  46  Units Shr - Ty Category                       3153 non-null   float64
#  47  Units Shr - Ty Subcategory                    5220 non-null   float64
# dtypes: float64(31), int64(8), object(9)
# memory usage: 19.8+ MB
# None
#           ClientId    Program Id      TacticId    CategoryId      VendorId  \
# count  54039.00000  54039.000000  54039.000000  54039.000000  53135.000000
# mean       6.03875   2213.326579   7247.566646      3.962601     45.138270
# std        0.27568   1714.596822   5360.286096      3.854720     53.527778
# min        6.00000    876.000000   2028.000000      1.000000      1.000000
# 25%        6.00000    994.000000   2867.000000      2.000000      1.000000
# 50%        6.00000   1544.000000   5557.000000      2.000000     32.000000
# 75%        6.00000   2373.000000   9281.000000      4.000000     63.000000
# max        8.00000   8210.000000  25783.000000     22.000000    256.000000
#
#        Total Impressions for Tactic  Total Tactic Spend  \
# count                  5.403900e+04        54039.000000
# mean                   3.408857e+07        33927.000842
# std                    3.680617e+08        61813.987485
# min                    0.000000e+00            0.000000
# 25%                    5.269400e+04         8714.000000
# 50%                    3.000000e+05        20000.000000
# 75%                    3.800838e+06        40000.000000
# max                    4.750000e+09       690000.000000
#
#        Total Tactic Insertion Cost  Total Tactic Redemption Cost  \
# count                 54039.000000                  54039.000000
# mean                  27540.179030                   6386.821813
# std                   61974.946222                  12328.696054
# min                       0.000000                      0.000000
# 25%                    4494.000000                      0.000000
# 50%                   10480.890000                      0.000000
# 75%                   29994.800000                   9750.000000
# max                  690000.000000                 151705.000000
#
#             BrandId  Nielsen_Week_Year    StoreCount         Weeks  \
# count  54039.000000       54039.000000  54031.000000  54039.000000
# mean     144.749144      202052.572716   1033.474764      8.902885
# std       81.678725          52.642826   1304.144639      5.067866
# min       95.000000      201940.000000      0.000000      1.000000
# 25%      107.000000      202022.000000      0.000000      6.000000
# 50%      126.000000      202056.000000      0.000000      8.000000
# 75%      142.000000      202083.000000   2277.000000     12.000000
# max      869.000000      202211.000000  15000.000000     61.000000
#
#        Impressions per Week  Brand Share of Program Budget  \
# count          5.403900e+04                   54039.000000
# mean           3.044121e+06                       0.239102
# std            3.048686e+07                       0.291679
# min            0.000000e+00                       0.000000
# 25%            7.064667e+03                       0.056904
# 50%            3.739900e+04                       0.123091
# 75%            5.371706e+05                       0.271429
# max            4.500000e+08                       1.000000
#
#        Brand Share of Total Tactic Spend  \
# count                       54039.000000
# mean                         7075.707566
# std                         14125.204066
# min                             0.000000
# 25%                           635.431163
# 50%                          2291.429059
# 75%                          6725.352668
# max                        187676.881500
#
#        Brand Share of Tactic Insertion Cost  \
# count                          54039.000000
# mean                            6081.785173
# std                            13789.562246
# min                                0.000000
# 25%                              321.889388
# 50%                             1200.018400
# 75%                             5000.000000
# max                           187676.881500
#
#        Brand Share of Tactic Redemption Cost  \
# count                           54039.000000
# mean                              993.922393
# std                              3232.831264
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                               859.193251
# max                             95277.041730
#
#        Weekly Brand Share of Total Tactic Spend  \
# count                              54039.000000
# mean                                1088.521203
# std                                 2296.768322
# min                                    0.000000
# 25%                                   74.301177
# 50%                                  292.379274
# 75%                                  978.627786
# max                                50449.524440
#
#        Weekly Brand Share of Tactic Insertion Cost  \
# count                                 54039.000000
# mean                                    950.747446
# std                                    2218.411884
# min                                       0.000000
# 25%                                      38.480838
# 50%                                     142.070897
# 75%                                     711.071381
# max                                   47867.115920
#
#        Weekly Brand Share of Tactic Redemption Cost   Total Sales  \
# count                                  54039.000000  2.051500e+04
# mean                                     137.773757  9.009213e+05
# std                                      547.988072  1.629737e+06
# min                                        0.000000  0.000000e+00
# 25%                                        0.000000  1.339515e+05
# 50%                                        0.000000  3.600820e+05
# 75%                                      105.826813  9.115499e+05
# max                                    30406.408710  1.490354e+07
#
#              Base $        Incr $         Units    Base Units     Incr Units  \
# count  2.051500e+04  2.051500e+04  2.051500e+04  2.051500e+04   20515.000000
# mean   8.448715e+05  5.604979e+04  1.984949e+05  1.773540e+05   21140.858499
# std    1.587220e+06  1.339727e+05  4.354113e+05  4.095281e+05   52768.586371
# min    0.000000e+00 -3.165051e+05  0.000000e+00  0.000000e+00  -65774.600000
# 25%    1.169285e+05  7.980300e+02  2.088150e+04  1.700529e+04     696.123500
# 50%    3.149042e+05  1.451030e+04  7.331000e+04  5.862474e+04    5035.200000
# 75%    7.813353e+05  5.966724e+04  1.814967e+05  1.316421e+05   19756.091000
# max    1.454355e+07  1.860190e+06  3.600584e+06  3.224530e+06  617893.501000
#
#        Avg Unit Price  Any Promo Units  %ACV Distribution  Any Promo %ACV  \
# count    20523.000000     2.052300e+04       20481.000000    20481.000000
# mean         5.651272     6.032207e+04          86.373085       45.409581
# std          2.231451     1.662932e+05          25.044837       33.745145
# min          0.000000     0.000000e+00           0.331000        0.000000
# 25%          4.000000     2.202813e+03          91.901000       12.753000
# 50%          5.149000     1.539920e+04          98.872000       43.668000
# 75%          7.119000     5.465139e+04          99.761000       74.771000
# max         14.957000     2.074647e+06         100.000000      100.000000
#
#        Disp w/o Feat %ACV  Feat & Disp %ACV  Feat w/o Disp %ACV  \
# count        20481.000000      20481.000000        20481.000000
# mean             2.082658          0.820302           17.774523
# std              5.432150          3.497597           27.201852
# min              0.000000          0.000000            0.000000
# 25%              0.000000          0.000000            0.000000
# 50%              0.000000          0.000000            0.900000
# 75%              1.900000          0.000000           26.047000
# max             66.782000         58.213000          100.000000
#
#        Price Decr Only %ACV  Number of UPCs Selling  $ Shr - Ty Subcategory  \
# count          20481.000000            20523.000000             5220.000000
# mean              36.872715               16.736686               17.930702
# std               31.021937               16.984060               15.821726
# min                0.000000                0.000000                0.002000
# 25%                7.571000                6.000000                9.538000
# 50%               30.984000               11.000000               14.962000
# 75%               61.200000               20.000000               21.865250
# max              100.000000               83.000000               99.826000
#
#        Units Shr - Ty Category  Units Shr - Ty Subcategory
# count              3153.000000                 5220.000000
# mean                 14.251900                   18.203257
# std                  10.706888                   16.162427
# min                   0.005000                    0.002000
# 25%                   6.822000                    8.891000
# 50%                  12.086000                   13.800000
# 75%                  20.517000                   24.000000
# max                  70.645000                   99.814000

# %%
cols = 5
rows = 10
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize=(cols * 6, rows * 6))
for i, col in enumerate(num_cols):
    ax = fig.add_subplot(rows, cols, i + 1)
    sns.histplot(x=df[col], ax=ax)
fig.tight_layout()
plt.show()

# %%
# these visualizations provide some clue as to how to model the large number
# of variables and to examine their relationships
corr = df.corr(method="spearman")
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# C:\Users\norri\AppData\Local\Temp\ipykernel_24268\2107138887.py:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cm
18_row0_col38, #T_75b18_row21_col0, #T_75b18_row22_col0, #T_75b18_row23_col0, #T_75b18_row24_col0, #T_75b18_row25_col0, #T_75b18_row26_col0, #T_75b18_row27_col0, #T_75b18_row28_col0, #T_75b18_row29_col0, #T_75b18_row30_col0, #T_75b18_row31_col0, #T_75b18_row32_col0, #T_75b18_row33_col0, #T_75b18_row34_col0, #T_75b18_row35_col0, #T_75b18_row36_col0, #T_75b18_row37_col0, #T_75b18_row38_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_75b18_row1_col2, #T_75b18_row26_col23, #T_75b18_row30_col34 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_75b18_row1_col3, #T_75b18_row4_col26, #T_75b18_row9_col33, #T_75b18_row11_col3, #T_75b18_row14_col31 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_75b18_row1_col4, #T_75b18_row1_col14, #T_75b18_row1_col19, #T_75b18_row5_col21, #T_75b18_row5_col22, #T_75b18_row5_col24, #T_75b18_row5_col25, #T_75b18_row6_col24, #T_75b18_row7_col21, #T_75b18_row12_col4, #T_75b18_row12_col5, #T_75b18_row14_col5, #T_75b18_row15_col1, #T_75b18_row17_col38, #T_75b18_row20_col38, #T_75b18_row22_col31, #T_75b18_row24_col8, #T_75b18_row24_col11, #T_75b18_row24_col31, #T_75b18_row24_col32, #T_75b18_row29_col13, #T_75b18_row35_col4, #T_75b18_row36_col30, #T_75b18_row37_col12, #T_75b18_row37_col13 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_75b18_row1_col5, #T_75b18_row13_col17, #T_75b18_row14_col33 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_75b18_row1_col6, #T_75b18_row2_col15, #T_75b18_row10_col33, #T_75b18_row11_col13, #T_75b18_row16_col21, #T_75b18_row16_col22, #T_75b18_row16_col24, #T_75b18_row21_col18, #T_75b18_row22_col18, #T_75b18_row24_col19, #T_75b18_row25_col18, #T_75b18_row26_col10, #T_75b18_row31_col37 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_75b18_row1_col7, #T_75b18_row2_col7, #T_75b18_row3_col8, #T_75b18_row3_col35, #T_75b18_row5_col32, #T_75b18_row8_col21, #T_75b18_row8_col25, #T_75b18_row10_col30, #T_75b18_row16_col0, #T_75b18_row16_col2, #T_75b18_row21_col15, #T_75b18_row22_col15, #T_75b18_row27_col29, #T_75b18_row27_col32, #T_75b18_row27_col33, #T_75b18_row30_col14 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_75b18_row1_col8, #T_75b18_r

# %% [markdown]
# ##### Imputation of missing values is too unreliable to base the rest of the
# ##### model on. Later tests will tell if there is any bias present. This is when
# ##### the most standout variables should be chosen for the model

# %%
# print(len(df))
# df = df.dropna(how='any', subset=['Impressions per Week'])
# df['Impressions per Week'].astype('float32', copy=True)
# df = df.dropna(how='any', subset=['%ACV Distribution'])
# df['%ACV Distribution'].astype('float32', copy=True)
# df = df.dropna(how='any', subset=['Units'])
# df['Units'].astype('float32', copy=True)
# df = df.dropna(how='any', subset=['Number of UPCs Selling'])
# df['Number of UPCs Selling'].astype('float32', copy=True)
# df = df.dropna(how='any', subset=['Total Sales'])
# df['Total Sales'].astype('float32', copy=True)
# df = df.dropna(how='any', subset=['Base $'])
# df['Base $'].astype('float32', copy=True)
# print(df.describe())
# print(df.info())
# ['Impressions per Week', 'Units', '%ACV Distribution',
#  'Number of UPCs Selling', 'Base $']

# %%
# most of the EDA techniques we'll use cannot handle categorical data, so dropping
# the categoricals and rerunning the correlation plot is valuable here
df_num = df.select_dtypes(exclude=object)
corr = df_num.corr()
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# C:\Users\norri\AppData\Local\Temp\ipykernel_24268\2104616834.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# <style type="text/css">
# #T_7f225_row0_col0, #T_7f225_row1_col1, #T_7f225_row2_col2, #T_7f225_row3_col3, #T_7f225_row4_col4, #T_7f225_row5_col5, #T_7f225_row6_col6, #T_7f225_row7_col7, #T_7f225_row8_col8, #T_7f225_row9_col9, #T_7f225_row10_col10, #T_7f225_row11_col11, #T_7f225_row12_col12, #T_7f225_row13_col13, #T_7f225_row14_col14, #T_7f225_row15_col15, #T_7f225_row16_col16, #T_7f225_row17_col17, #T_7f225_row18_col18, #T_7f225_row19_col19, #T_7f225_row20_col20, #T_7f225_row21_col21, #T_7f225_row21_col22, #T_7f225_row22_col21, #T_7f225_row22_col22, #T_7f225_row23_col23, #T_7f225_row24_col24, #T_7f225_row25_col25, #T_7f225_row26_col26, #T_7f225_row27_col27, #T_7f225_row28_col28, #T_7f225_row29_col29, #T_7f225_row30_col30, #T_7f225_row31_col31, #T_7f225_row32_col32, #T_7f225_row33_col33, #T_7f225_row34_col34, #T_7f225_row35_col35, #T_7f225_row36_col36, #T_7f225_row37_col37, #T_7f225_row38_col38 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7f225_row0_col1, #T_7f225_row2_col27, #T_7f225_row4_col27, #T_7f225_row6_col27, #T_7f225_row7_col27, #T_7f225_row10_col36, #T_7f225_row11_col36, #T_7f225_row13_col3, #T_7f225_row15_col21, #T_7f225_row18_col3, #T_7f225_row22_col11, #T_7f225_row22_col15, #T_7f225_row23_col8, #T_7f225_row26_col4, #T_7f225_row28_col11, #T_7f225_row30_col36, #T_7f225_row34_col36, #T_7f225_row37_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7f225_row0_col2, #T_7f225_row5_col4, #T_7f225_row6_col35, #T_7f225_row7_col35, #T_7f225_row13_col4, #T_7f225_row13_col8, #T_7f225_row13_col15, #T_7f225_row16_col29, #T_7f225_row18_col29, #T_7f225_row22_col34, #T_7f225_row28_col12, #T_7f225_row30_col21, #T_7f225_row32_col12, #T_7f225_row34_col31 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7f225_row0_col3, #T_7f225_row3_col7, #T_7f225_row4_col26, #T_7f225_row5_col8, #T_7f225_row5_col12, #T_7f225_row8_col26, #T_7f225_row9_col27, #T_7f225_row13_col19, #T_7f225_row15_col29, #T_7f225_row21_col6, #T_7f225_row22_col8, #T_7f225_row24_col6, #T_7f225_row24_col9, #T_7f225_row26_col2, #T_7f225_row36_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7f225_row0_col4, #T_7f225_row4_col19, #T_7f225_row18_col7, #T_7f225_row23_col29, #T_7f225_row24_col4, #T_7f225_row25_col23, #T_7f225_row30_col38, #T_7f225_row31_col21, #T_7f225_row36_col25, #T_7f225_row37_col14 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T
sns.kdeplot(ax=axes[0, 1], x='Impressions per Week', data=df_num)
sns.kdeplot(ax=axes[0, 2], x='Brand Share of Tactic Redemption Cost', data=df_num)
sns.kdeplot(ax=axes[1, 0], x='Any Promo Units', data=df_num)
sns.kdeplot(ax=axes[1, 1], x='%ACV Distribution', data=df_num)
sns.kdeplot(ax=axes[1, 2], x='Number of UPCs Selling', data=df_num)
plt.show()

# %% [markdown]
# ### These kde plots will a primary tool in determining the likelihood
# ### distributions and giving information on the prior

# %%
df_all = df_num.dropna().astype(dtype='int32')

features = ['Impressions per Week', 'Brand Share of Tactic Redemption Cost',
            'Any Promo Units', '%ACV Distribution', 'Number of UPCs Selling']
target = 'Total Sales'
df_all = df_all[features + [target]]
df_train, df_test = train_test_split(df_all, test_size=0.15)

X_train, y_train = df_train.drop('Total Sales',axis=1), df_train['Total Sales']
X_test, y_test = df_test.drop('Total Sales',axis=1), df_test['Total Sales']

rf = RandomForestClassifier(n_estimators=100, n_jobs=-1,
                            #                            max_features=X_train.shape[1]-1,
                            max_features=1.0,
                            min_samples_leaf=10, oob_score=True)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=1.0, min_samples_leaf=10, n_jobs=-1,
#                        oob_score=True)

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
                       max_depth=None, max_features=1.0, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_samples_leaf=10, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
                       oob_score=True, random_state=None, verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(max_features=1.0, min_samples_leaf=10, n_jobs=-1,
#                        oob_score=True)

# %% [markdown]
# ### This importance plot from a RandomForestClassifier is one of the key
# ### ways we'll understand which variables are the most important

# %%
I = importances(rf, X_test, y_test)
plot_importances(I)

# %% [markdown]
# #### With an array of all the variables, I could make an importance plot
# #### for everything but the categorical variables, but I would have to change
# #### the dependent variable each time. Remember that we dropped missing values
# #### instead of dropping columns, which we could do with a column that did not
# #### make an impression on the correlation plot or importance plot

# %%
I = pd.DataFrame()

I['Feature'] = X_train.columns
I['Importance'] = df_all.feature_importances_
I = I.sort_values('Importance', ascending=False)
I = I.set_index('Feature')
viz = plot_importances(I)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [114], in <cell line: 4>()
#       1 I = pd.DataFrame()
#       3 I['Feature'] = X_train.columns
# ----> 4 I['Importance'] = df_all.feature_importances_
#       5 I = I.sort_values('Importance', ascending=False)
#       6 I = I.set_index('Feature')
#
# File ~\.conda\envs\Attribution_EDA\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'feature_importances_'

# %% [markdown]
# #### Our categorical variables shouldn't be forgotten; just alter the threshold
# #### down from 250 if the axis titles start to look messy

# %%
for col in df.select_dtypes(include='object'):
    if df[col].nunique() <= 250:
        sns.countplot(y=col, data=df)
        plt.show()

# %%
X = np.array(df_num['Total Sales'])
Y = np.array(df_num['Any Promo Units'])
Z = np.array(df_num['%ACV Distribution'])
temp = np.vstack((X, Y))
letters = (np.vstack((temp, Z))).T

# pca = PCA(n_components=3, svd_solver='full')
# plt(pca.fit(letters))

# lda = LinearDiscriminantAnalysis(n_components=2)
# X_r2 = lda.fit(X, Y).transform(X)
#
# X_r.plt()
# X_r2.plt()
# Out:
# C:\Users\norri\.conda\envs\Attribution_EDA\lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
