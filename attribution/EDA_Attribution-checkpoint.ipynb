# %% [markdown]
# #### The purpose of this EDA notebook is the following:
# - Better understand the nature of the relationship between the independent variables
# - Create an initial model with reasonable economic assumptions that may be dropped in later versions
# - Explore methods of imputation for missing variables to provide more data samples
# - Avoid linear combinations that might be more difficult to spot in the Bayesian Modeling process
# - Establish a reasonable measure of variable importance, which along with correlation plots may inform initial hierarchies
# - Create visualizations of poor quality data and also establish probability distributions for the likelihood function

# %%
# sklearn, pandas, numpy, matplotlib, and seaborn are natural choices for EDA
# though we will add quite a few more
import pandas as pd
import numpy as np
from rfpimp import plot_corr_heatmap
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer, load_boston
from sklearn.metrics import accuracy_score
from rfpimp import *
from sklearn.inspection import permutation_importance
# import category_encoders as ce
from matplotlib import pyplot as plt


# will add more here later on

# %% [markdown]
# #### In an effort to generalize for future EDA, 'df' makes it easier to debug

# %%
df = pd.read_csv('C:/Users/norri/Desktop/cortex_Push.csv')
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54039 entries, 0 to 54038
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ClientId                                      54039 non-null  int64
#  1   Program Id                                    54039 non-null  int64
#  2   Program Name                                  54039 non-null  object
#  3   Retailers                                     54039 non-null  object
#  4   TacticId                                      54039 non-null  int64
#  5   Tactic                                        54039 non-null  object
#  6   CategoryId                                    54039 non-null  int64
#  7   Tactic Category                               54039 non-null  object
#  8   VendorId                                      53135 non-null  float64
#  9   Vendor                                        54039 non-null  object
#  10  Total Impressions for Tactic                  54039 non-null  int64
#  11  Total Tactic Spend                            54039 non-null  float64
#  12  Total Tactic Insertion Cost                   54039 non-null  float64
#  13  Total Tactic Redemption Cost                  54039 non-null  float64
#  14  Tactic Start Date                             54039 non-null  object
#  15  Tactic End Date                               54039 non-null  object
#  16  BrandId                                       54039 non-null  int64
#  17  Brand                                         54039 non-null  object
#  18  Nielsen_Week_Year                             54039 non-null  int64
#  19  StoreCount                                    54031 non-null  float64
#  20  RMN                                           54039 non-null  object
#  21  Weeks                                         54039 non-null  int64
#  22  Impressions per Week                          54039 non-null  float64
#  23  Brand Share of Program Budget                 54039 non-null  float64
#  24  Brand Share of Total Tactic Spend             54039 non-null  float64
#  25  Brand Share of Tactic Insertion Cost          54039 non-null  float64
#  26  Brand Share of Tactic Redemption Cost         54039 non-null  float64
#  27  Weekly Brand Share of Total Tactic Spend      54039 non-null  float64
#  28  Weekly Brand Share of Tactic Insertion Cost   54039 non-null  float64
#  29  Weekly Brand Share of Tactic Redemption Cost  54039 non-null  float64
#  30  Sales                                         54039 non-null  float64
#  31  Base $                                        20515 non-null  float64
#  32  Incr $                                        20515 non-null  float64
#  33  Units                                         20515 non-null  float64
#  34  Base Units                                    20515 non-null  float64
#  35  Incr Units                                    20515 non-null  float64
#  36  Avg Unit Price                                20523 non-null  float64
#  37  Any Promo Units                               20523 non-null  float64
#  38  %ACV Distribution                             20481 non-null  float64
#  39  Any Promo %ACV                                20481 non-null  float64
#  40  Disp w/o Feat %ACV                            20481 non-null  float64
#  41  Feat & Disp %ACV                              20481 non-null  float64
#  42  Feat w/o Disp %ACV                            20481 non-null  float64
#  43  Price Decr Only %ACV                          20481 non-null  float64
#  44  Number of UPCs Selling                        20523 non-null  float64
#  45  $ Shr - Ty Subcategory                        5220 non-null   float64
#  46  Units Shr - Ty Category                       3153 non-null   float64
#  47  Units Shr - Ty Subcategory                    5220 non-null   float64
# dtypes: float64(31), int64(8), object(9)
# memory usage: 19.8+ MB
# None
#           ClientId    Program Id      TacticId    CategoryId      VendorId  \
# count  54039.00000  54039.000000  54039.000000  54039.000000  53135.000000
# mean       6.03875   2213.326579   7247.566646      3.962601     45.138270
# std        0.27568   1714.596822   5360.286096      3.854720     53.527778
# min        6.00000    876.000000   2028.000000      1.000000      1.000000
# 25%        6.00000    994.000000   2867.000000      2.000000      1.000000
# 50%        6.00000   1544.000000   5557.000000      2.000000     32.000000
# 75%        6.00000   2373.000000   9281.000000      4.000000     63.000000
# max        8.00000   8210.000000  25783.000000     22.000000    256.000000
#
#        Total Impressions for Tactic  Total Tactic Spend  \
# count                  5.403900e+04        54039.000000
# mean                   3.408857e+07        33927.000842
# std                    3.680617e+08        61813.987485
# min                    0.000000e+00            0.000000
# 25%                    5.269400e+04         8714.000000
# 50%                    3.000000e+05        20000.000000
# 75%                    3.800838e+06        40000.000000
# max                    4.750000e+09       690000.000000
#
#        Total Tactic Insertion Cost  Total Tactic Redemption Cost  \
# count                 54039.000000                  54039.000000
# mean                  27540.179030                   6386.821813
# std                   61974.946222                  12328.696054
# min                       0.000000                      0.000000
# 25%                    4494.000000                      0.000000
# 50%                   10480.890000                      0.000000
# 75%                   29994.800000                   9750.000000
# max                  690000.000000                 151705.000000
#
#             BrandId  ...  %ACV Distribution  Any Promo %ACV  \
# count  54039.000000  ...       20481.000000    20481.000000
# mean     144.749144  ...          86.373085       45.409581
# std       81.678725  ...          25.044837       33.745145
# min       95.000000  ...           0.331000        0.000000
# 25%      107.000000  ...          91.901000       12.753000
# 50%      126.000000  ...          98.872000       43.668000
# 75%      142.000000  ...          99.761000       74.771000
# max      869.000000  ...         100.000000      100.000000
#
#        Disp w/o Feat %ACV  Feat & Disp %ACV  Feat w/o Disp %ACV  \
# count        20481.000000      20481.000000        20481.000000
# mean             2.082658          0.820302           17.774523
# std              5.432150          3.497597           27.201852
# min              0.000000          0.000000            0.000000
# 25%              0.000000          0.000000            0.000000
# 50%              0.000000          0.000000            0.900000
# 75%              1.900000          0.000000           26.047000
# max             66.782000         58.213000          100.000000
#
#        Price Decr Only %ACV  Number of UPCs Selling  $ Shr - Ty Subcategory  \
# count          20481.000000            20523.000000             5220.000000
# mean              36.872715               16.736686               17.930702
# std               31.021937               16.984060               15.821726
# min                0.000000                0.000000                0.002000
# 25%                7.571000                6.000000                9.538000
# 50%               30.984000               11.000000               14.962000
# 75%               61.200000               20.000000               21.865250
# max              100.000000               83.000000               99.826000
#
#        Units Shr - Ty Category  Units Shr - Ty Subcategory
# count              3153.000000                 5220.000000
# mean                 14.251900                   18.203257
# std                  10.706888                   16.162427
# min                   0.005000                    0.002000
# 25%                   6.822000                    8.891000
# 50%                  12.086000                   13.800000
# 75%                  20.517000                   24.000000
# max                  70.645000                   99.814000
#
# [8 rows x 39 columns]

# %%
print(df.isnull().sum())
# Out:
# ClientId                                            0
# Program Id                                          0
# Program Name                                        0
# Retailers                                           0
# TacticId                                            0
# Tactic                                              0
# CategoryId                                          0
# Tactic Category                                     0
# VendorId                                          904
# Vendor                                              0
# Total Impressions for Tactic                        0
# Total Tactic Spend                                  0
# Total Tactic Insertion Cost                         0
# Total Tactic Redemption Cost                        0
# Tactic Start Date                                   0
# Tactic End Date                                     0
# BrandId                                             0
# Brand                                               0
# Nielsen_Week_Year                                   0
# StoreCount                                          8
# RMN                                                 0
# Weeks                                               0
# Impressions per Week                                0
# Brand Share of Program Budget                       0
# Brand Share of Total Tactic Spend                   0
# Brand Share of Tactic Insertion Cost                0
# Brand Share of Tactic Redemption Cost               0
# Weekly Brand Share of Total Tactic Spend            0
# Weekly Brand Share of Tactic Insertion Cost         0
# Weekly Brand Share of Tactic Redemption Cost        0
# Sales                                               0
# Base $                                          33524
# Incr $                                          33524
# Units                                           33524
# Base Units                                      33524
# Incr Units                                      33524
# Avg Unit Price                                  33516
# Any Promo Units                                 33516
# %ACV Distribution                               33558
# Any Promo %ACV                                  33558
# Disp w/o Feat %ACV                              33558
# Feat & Disp %ACV                                33558
# Feat w/o Disp %ACV                              33558
# Price Decr Only %ACV                            33558
# Number of UPCs Selling                          33516
# $ Shr - Ty Subcategory                          48819
# Units Shr - Ty Category                         50886
# Units Shr - Ty Subcategory                      48819
# dtype: int64

# %%
corr = df.corr(method="spearman")
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# C:\Users\norri\AppData\Local\Temp\ipykernel_10532\1002829753.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# <style type="text/css">
# #T_8cd85_row0_col0, #T_8cd85_row1_col1, #T_8cd85_row2_col2, #T_8cd85_row3_col3, #T_8cd85_row4_col4, #T_8cd85_row5_col5, #T_8cd85_row6_col6, #T_8cd85_row7_col7, #T_8cd85_row8_col8, #T_8cd85_row9_col9, #T_8cd85_row10_col10, #T_8cd85_row11_col11, #T_8cd85_row12_col12, #T_8cd85_row13_col13, #T_8cd85_row14_col14, #T_8cd85_row15_col15, #T_8cd85_row16_col16, #T_8cd85_row17_col17, #T_8cd85_row17_col20, #T_8cd85_row18_col18, #T_8cd85_row19_col19, #T_8cd85_row20_col17, #T_8cd85_row20_col20, #T_8cd85_row21_col21, #T_8cd85_row22_col22, #T_8cd85_row23_col23, #T_8cd85_row24_col24, #T_8cd85_row25_col25, #T_8cd85_row26_col26, #T_8cd85_row27_col27, #T_8cd85_row28_col28, #T_8cd85_row29_col29, #T_8cd85_row30_col30, #T_8cd85_row31_col31, #T_8cd85_row32_col32, #T_8cd85_row33_col33, #T_8cd85_row34_col34, #T_8cd85_row35_col35, #T_8cd85_row36_col36, #T_8cd85_row37_col37, #T_8cd85_row38_col38 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8cd85_row0_col1, #T_8cd85_row2_col4, #T_8cd85_row5_col18, #T_8cd85_row12_col24, #T_8cd85_row14_col20, #T_8cd85_row27_col17, #T_8cd85_row34_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T
{
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_8cd85_row1_col3, #T_8cd85_row3_col1, #T_8cd85_row4_col26, #T_8cd85_row9_col33, #T_8cd85_row11_col3, #T_8cd85_row14_col31 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8cd85_row1_col4, #T_8cd85_row1_col14, #T_8cd85_row1_col19, #T_8cd85_row5_col22, #T_8cd85_row5_col24, #T_8cd85_row5_col25, #T_8cd85_row6_col24, #T_8cd85_row12_col4, #T_8cd85_row12_col5, #T_8cd85_row14_col5, #T_8cd85_row17_col38, #T_8cd85_row20_col38, #T_8cd85_row22_col31, #T_8cd85_row24_col8, #T_8cd85_row24_col11, #T_8cd85_row24_col31, #T_8cd85_row24_col32, #T_8cd85_row29_col13, #T_8cd85_row34_col1, #T_8cd85_row35_col4, #T_8cd85_row36_col30, #T_8cd85_row37_col12, #T_8cd85_row37_col13 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_8cd85_row1_col5, #T_8cd85_row13_col17, #T_8cd85_row14_col33, #T_8cd85_row27_col10 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_8cd85_row1_col6, #T_8cd85_row2_col15, #T_8cd85_row10_col33, #T_8cd85_row11_col13, #T_8cd85_row16_col10, #T_8cd85_row16_col22, #T_8cd85_row16_col24, #T_8cd85_row22_col18, #T_8cd85_row24_col19, #T_8cd85_row25_col18, #T_8cd85_row31_col10, #T_8cd85_row31_col37 {
#   background-color: #8caffe;
#   color: #000000;
# }

# %% [markdown]
# #### Imputation of missing values is too unreliable to base the rest of the model on. Later tests on uniqueness will tell if there is any bias present.

# %%
print(len(df))
df = df.dropna(how='all', subset=['Impressions per Week'])
df['Impressions per Week'].astype('float32', copy=True)
df = df.dropna(how='all', subset=['%ACV Distribution'])
df['%ACV Distribution'].astype('float32', copy=True)
df = df.dropna(how='all', subset=['Units'])
df['Units'].astype('float32', copy=True)
df = df.dropna(how='all', subset=['Number of UPCs Selling'])
df['Number of UPCs Selling'].astype('float32', copy=True)
df = df.dropna(how='all', subset=['Sales'])
df['Sales'].astype('float32', copy=True)
df = df.dropna(how='all', subset=['Base $'])
df['Base $'].astype('float32', copy=True)
print(df.describe())
print(df.info())
['Impressions per Week','Units','%ACV Distribution','Number of UPCs Selling','Base $']
# Out:
# 54039
#        ClientId    Program Id      TacticId    CategoryId      VendorId  \
# count   20481.0  20481.000000  20481.000000  20481.000000  20113.000000
# mean        6.0   1350.745813   4937.602314      5.037401     53.179088
# std         0.0    470.037476   2440.248933      4.536470     38.529454
# min         6.0    876.000000   2028.000000      1.000000      2.000000
# 25%         6.0    966.000000   2391.000000      2.000000      7.000000
# 50%         6.0   1214.000000   5403.000000      3.000000     63.000000
# 75%         6.0   1592.000000   6336.000000      6.000000     69.000000
# max         6.0   4386.000000  20348.000000     22.000000    231.000000
#
#        Total Impressions for Tactic  Total Tactic Spend  \
# count                  2.048100e+04        20481.000000
# mean                   8.538506e+07        38588.477732
# std                    5.941899e+08        92978.100382
# min                    0.000000e+00            0.000000
# 25%                    8.000000e+05         1010.000000
# 50%                    2.233596e+06        14136.000000
# 75%                    7.874389e+06        38703.000000
# max                    4.750000e+09       690000.000000
#
#        Total Tactic Insertion Cost  Total Tactic Redemption Cost  \
# count                 20481.000000                  20481.000000
# mean                  37043.949164                   1544.528568
# std                   92511.112266                  10911.405500
# min                       0.000000                      0.000000
# 25%                     491.330000                      0.000000
# 50%                   11844.000000                      0.000000
# 75%                   35000.000000                      0.000000
# max                  690000.000000                 151705.000000
#
#             BrandId  ...  %ACV Distribution  Any Promo %ACV  \
# count  20481.000000  ...       20481.000000    20481.000000
# mean     136.178019  ...          86.373085       45.409581
# std       66.162786  ...          25.044837       33.745145
# min       96.000000  ...           0.331000        0.000000
# 25%      107.000000  ...          91.901000       12.753000
# 50%      122.000000  ...          98.872000       43.668000
# 75%      142.000000  ...          99.761000       74.771000
# max      543.000000  ...         100.000000      100.000000
#
#        Disp w/o Feat %ACV  Feat & Disp %ACV  Feat w/o Disp %ACV  \
# count        20481.000000      20481.000000        20481.000000
# mean             2.082658          0.820302           17.774523
# std              5.432150          3.497597           27.201852
# min              0.000000          0.000000            0.000000
# 25%              0.000000          0.000000            0.000000
# 50%              0.000000          0.000000            0.900000
# 75%              1.900000          0.000000           26.047000
# max             66.782000         58.213000          100.000000
#
#        Price Decr Only %ACV  Number of UPCs Selling  $ Shr - Ty Subcategory  \
# count          20481.000000            20481.000000             5220.000000
# mean              36.872715               16.771007               17.930702
# std               31.021937               16.984529               15.821726
# min                0.000000                1.000000                0.002000
# 25%                7.571000                6.000000                9.538000
# 50%               30.984000               11.000000               14.962000
# 75%               61.200000               20.000000               21.865250
# max              100.000000               83.000000               99.826000
#
#        Units Shr - Ty Category  Units Shr - Ty Subcategory
# count              3153.000000                 5220.000000
# mean                 14.251900                   18.203257
# std                  10.706888                   16.162427
# min                   0.005000                    0.002000
# 25%                   6.822000                    8.891000
# 50%                  12.086000                   13.800000
# 75%                  20.517000                   24.000000
# max                  70.645000                   99.814000
#
# [8 rows x 39 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20481 entries, 34 to 20514
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ClientId                                      20481 non-null  int64
#  1   Program Id                                    20481 non-null  int64
#  2   Program Name                                  20481 non-null  object
#  3   Retailers                                     20481 non-null  object
#  4   TacticId                                      20481 non-null  int64
#  5   Tactic                                        20481 non-null  object
#  6   CategoryId                                    20481 non-null  int64
#  7   Tactic Category                               20481 non-null  object
#  8   VendorId                                      20113 non-null  float64
#  9   Vendor                                        20481 non-null  object
#  10  Total Impressions for Tactic                  20481 non-null  int64
#  11  Total Tactic Spend                            20481 non-null  float64
#  12  Total Tactic Insertion Cost                   20481 non-null  float64
#  13  Total Tactic Redemption Cost                  20481 non-null  float64
#  14  Tactic Start Date                             20481 non-null  object
#  15  Tactic End Date                               20481 non-null  object
#  16  BrandId                                       20481 non-null  int64
#  17  Brand                                         20481 non-null  object
#  18  Nielsen_Week_Year                             20481 non-null  int64
#  19  StoreCount                                    20481 non-null  float64
#  20  RMN                                           20481 non-null  object
#  21  Weeks                                         20481 non-null  int64
#  22  Impressions per Week                          20481 non-null  float64
#  23  Brand Share of Program Budget                 20481 non-null  float64
#  24  Brand Share of Total Tactic Spend             20481 non-null  float64
#  25  Brand Share of Tactic Insertion Cost          20481 non-null  float64
#  26  Brand Share of Tactic Redemption Cost         20481 non-null  float64
#  27  Weekly Brand Share of Total Tactic Spend      20481 non-null  float64
#  28  Weekly Brand Share of Tactic Insertion Cost   20481 non-null  float64
#  29  Weekly Brand Share of Tactic Redemption Cost  20481 non-null  float64
#  30  Sales                                         20481 non-null  float64
#  31  Base $                                        20481 non-null  float64
#  32  Incr $                                        20481 non-null  float64
#  33  Units                                         20481 non-null  float64
#  34  Base Units                                    20481 non-null  float64
#  35  Incr Units                                    20481 non-null  float64
#  36  Avg Unit Price                                20481 non-null  float64
#  37  Any Promo Units                               20481 non-null  float64
#  38  %ACV Distribution                             20481 non-null  float64
#  39  Any Promo %ACV                                20481 non-null  float64
#  40  Disp w/o Feat %ACV                            20481 non-null  float64
#  41  Feat & Disp %ACV                              20481 non-null  float64
#  42  Feat w/o Disp %ACV                            20481 non-null  float64
#  43  Price Decr Only %ACV                          20481 non-null  float64
#  44  Number of UPCs Selling                        20481 non-null  float64
#  45  $ Shr - Ty Subcategory                        5220 non-null   float64
#  46  Units Shr - Ty Category                       3153 non-null   float64
#  47  Units Shr - Ty Subcategory                    5220 non-null   float64
# dtypes: float64(31), int64(8), object(9)
# memory usage: 7.7+ MB
# None
# ['Impressions per Week',
#  'Units',
#  '%ACV Distribution',
#  'Number of UPCs Selling',
#  'Base $']

# %%
corr = df.corr(method="spearman")
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# C:\Users\norri\AppData\Local\Temp\ipykernel_10532\1390628132.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# C:\Users\norri\.conda\envs\Attribution_EDA\lib\site-packages\pandas\io\formats\style.py:3554: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\norri\.conda\envs\Attribution_EDA\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_02b9c_row0_col0, #T_02b9c_row0_col1, #T_02b9c_row0_col2, #T_02b9c_row0_col3, #T_02b9c_row0_col4, #T_02b9c_row0_col5, #T_02b9c_row0_col6, #T_02b9c_row0_col7, #T_02b9c_row0_col8, #T_02b9c_row0_col9, #T_02b9c_row0_col10, #T_02b9c_row0_col11, #T_02b9c_row0_col12, #T_02b9c_row0_col13, #T_02b9c_row0_col14, #T_02b9c_row0_col15, #T_02b9c_row0_col16, #T_02b9c_row0_col17, #T_02b9c_row0_col18, #T_02b9c_row0_col19, #T_02b9c_row0_col20, #T_02b9c_row0_col21, #T_02b9c_row0_col22, #T_02b9c_row0_col23, #T_02b9c_row0_col24, #T_02b9c_row0_col25, #T_02b9c_row0_col26, #T_02b9c_row0_col27, #T_02b9c_row0_col28, #T_02b9c_row0_col29, #T_02b9c_row0_col30, #T_02b9c_row0_col31, #T_02b9c_row0_col32, #T_02b9c_row0_col33, #T_02b9c_row0_col34, #T_02b9c_row0_col35, #T_02b9c_row0_col36, #T_02b9c_row0_col37, #T_02b9c_row0_col38, #T_02b9c_row1_col0, #T_02b9c_row2_col0, #T_02b9c_row3_col0, #T_02b9c_row4_col0, #T_02b9c_row5_col0, #T_02b9c_row6_col0, #T_02b9c_row7_col0, #T_02b9c_row8_col0, #T_02b9c_row9_col0, #T_02b9c_row10_col0, #T_02b9c_row11_col0, #T_02b
{
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_02b9c_row1_col22, #T_02b9c_row1_col28, #T_02b9c_row1_col37, #T_02b9c_row4_col27, #T_02b9c_row6_col27, #T_02b9c_row7_col27, #T_02b9c_row15_col8, #T_02b9c_row17_col16, #T_02b9c_row20_col16, #T_02b9c_row23_col27, #T_02b9c_row24_col2, #T_02b9c_row24_col10, #T_02b9c_row27_col16, #T_02b9c_row37_col11 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_02b9c_row1_col23, #T_02b9c_row1_col34, #T_02b9c_row7_col10, #T_02b9c_row12_col1, #T_02b9c_row12_col29, #T_02b9c_row16_col21, #T_02b9c_row16_col22, #T_02b9c_row16_col24 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_02b9c_row1_col24, #T_02b9c_row3_col27, #T_02b9c_row10_col28, #T_02b9c_row11_col27, #T_02b9c_row21_col19, #T_02b9c_row22_col19, #T_02b9c_row25_col10, #T_02b9c_row25_col19, #T_02b9c_row25_col32, #T_02b9c_row27_col15, #T_02b9c_row35_col27, #T_02b9c_row38_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_02b9c_row1_col25, #T_02b9c_row2_col9, #T_02b9c_row2_col34, #T_02b9c_row11_col23, #T_02b9c_row14_col3, #T_02b9c_row14_col8, #T_02b9c_row18_col17, #T_02b9c_row18_col20, #T_02b9c_row33_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_02b9c_row1_col27, #T_02b9c_row3_col22, #T_02b9c_row8_col16, #T_02b9c_row11_col29, #T_02b9c_row11_col34, #T_02b9c_row25_col4, #T_02b9c_row33_col27,

# %%
df_num = df.select_dtypes(exclude=object)
corr = df_num.corr()
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# C:\Users\norri\AppData\Local\Temp\ipykernel_10532\3049632806.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# <style type="text/css">
# #T_920e9_row0_col0, #T_920e9_row0_col1, #T_920e9_row0_col2, #T_920e9_row0_col3, #T_920e9_row0_col4, #T_920e9_row0_col5, #T_920e9_row0_col6, #T_920e9_row0_col7, #T_920e9_row0_col8, #T_920e9_row0_col9, #T_920e9_row0_col10, #T_920e9_row0_col11, #T_920e9_row0_col12, #T_920e9_row0_col13, #T_920e9_row0_col14, #T_920e9_row0_col15, #T_920e9_row0_col16, #T_920e9_row0_col17, #T_920e9_row0_col18, #T_920e9_row0_col19, #T_920e9_row0_col20, #T_920e9_row0_col21, #T_920e9_row0_col22, #T_920e9_row0_col23, #T_920e9_row0_col24, #T_920e9_row0_col25, #T_920e9_row0_col26, #T_920e9_row0_col27, #T_920e9_row0_col28, #T_920e9_row0_col29, #T_920e9_row0_col30, #T_920e9_row0_col31, #T_920e9_row0_col32, #T_920e9_row0_col33, #T_920e9_row0_col34, #T_920e9_row0_col35, #T_920e9_row0_col36, #T_920e9_row0_col37, #T_920e9_row0_col38, #T_920e9_row1_col0, #T_920e9_row2_col0, #T_920e9_row3_col0, #T_920e9_row4_col0, #T_920e9_row5_col0, #T_920e9_row6_col0, #T_920e9_row7_col0, #T_920e9_row8_col0, #T_920e9_row9_col0, #T_920e9_row10_col0, #T_920e9_row11_col0, #T_920e9_row12_col0, #T_920e9_row13_col0, #T_920e9_row14_col0, #T_920e9_row15_col0, #T_920e9_row16_col0, #T_920e9_row17_col0, #T_920e9_row18_col0, #T_920e9_row19_col0, #T_920e9
{
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_920e9_row1_col19, #T_920e9_row1_col28, #T_920e9_row5_col19, #T_920e9_row6_col26, #T_920e9_row7_col26, #T_920e9_row10_col34, #T_920e9_row11_col9, #T_920e9_row12_col1, #T_920e9_row12_col34, #T_920e9_row13_col3, #T_920e9_row15_col20, #T_920e9_row21_col6, #T_920e9_row21_col11, #T_920e9_row21_col27, #T_920e9_row22_col30, #T_920e9_row26_col11, #T_920e9_row28_col4, #T_920e9_row31_col33, #T_920e9_row35_col27, #T_920e9_row36_col31 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_920e9_row1_col21, #T_920e9_row4_col3, #T_920e9_row4_col20, #T_920e9_row8_col3, #T_920e9_row8_col32, #T_920e9_row10_col15, #T_920e9_row12_col6, #T_920e9_row19_col17, #T_920e9_row30_col14, #T_920e9_row30_col17, #T_920e9_row33_col4, #T_920e9_row34_col18, #T_920e9_row35_col3, #T_920e9_row35_col18, #T_920e9_row36_col27 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_920e9_row1_col23, #T

# %%
viz = plot_corr_heatmap(df_num, figsize=(15,15))
viz.view()

# %%
segment = [var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(segment)))
print('The categorical variables are :\n\n', segment)
print(df[segment].isnull().sum())
# Out:
# There are 9 categorical variables
#
# The categorical variables are :
#
#  ['Program Name', 'Retailers', 'Tactic', 'Tactic Category', 'Vendor', 'Tactic Start Date', 'Tactic End Date', 'Brand', 'RMN']
# Program Name         0
# Retailers            0
# Tactic               0
# Tactic Category      0
# Vendor               0
# Tactic Start Date    0
# Tactic End Date      0
# Brand                0
# RMN                  0
# dtype: int64

# %%
integer = [var for var in df.columns if df[var].dtype=='int64']
print('There are {} integer variables\n'.format(len(integer)))
print('The integer variables are :\n\n', integer)
print(df[integer].isnull().sum())
# Out:
# There are 8 integer variables
#
# The integer variables are :
#
#  ['ClientId', 'Program Id', 'TacticId', 'CategoryId', 'Total Impressions for Tactic', 'BrandId', 'Nielsen_Week_Year', 'Weeks']
# ClientId                        0
# Program Id                      0
# TacticId                        0
# CategoryId                      0
# Total Impressions for Tactic    0
# BrandId                         0
# Nielsen_Week_Year               0
# Weeks                           0
# dtype: int64

# %%
fp = [var for var in df.columns if df[var].dtype=='float64']
print('There are {} float variables\n'.format(len(fp)))
print('The float variables are :\n\n', fp)
print(df[fp].isnull().sum())
# Out:
# There are 31 float variables
#
# The float variables are :
#
#  ['VendorId', 'Total Tactic Spend', 'Total Tactic Insertion Cost', 'Total Tactic Redemption Cost', 'StoreCount', 'Impressions per Week', 'Brand Share of Program Budget', 'Brand Share of Total Tactic Spend', 'Brand Share of Tactic Insertion Cost', 'Brand Share of Tactic Redemption Cost', 'Weekly Brand Share of Total Tactic Spend', 'Weekly Brand Share of Tactic Insertion Cost', 'Weekly Brand Share of Tactic Redemption Cost', 'Sales', 'Base $', 'Incr $', 'Units', 'Base Units', 'Incr Units', 'Avg Unit Price', 'Any Promo Units', '%ACV Distribution', 'Any Promo %ACV', 'Disp w/o Feat %ACV', 'Feat & Disp %ACV', 'Feat w/o Disp %ACV', 'Price Decr Only %ACV', 'Number of UPCs Selling', '$ Shr - Ty Subcategory', 'Units Shr - Ty Category', 'Units Shr - Ty Subcategory']
# VendorId                                          368
# Total Tactic Spend                                  0
# Total Tactic Insertion Cost                         0
# Total Tactic Redemption Cost                        0
# StoreCount                                          0
# Impressions per Week                                0
# Brand Share of Program Budget                       0
# Brand Share of Total Tactic Spend                   0
# Brand Share of Tactic Insertion Cost                0
# Brand Share of Tactic Redemption Cost               0
# Weekly Brand Share of Total Tactic Spend            0
# Weekly Brand Share of Tactic Insertion Cost         0
# Weekly Brand Share of Tactic Redemption Cost        0
# Sales                                               0
# Base $                                              0
# Incr $                                              0
# Units                                               0
# Base Units                                          0
# Incr Units                                          0
# Avg Unit Price                                      0
# Any Promo Units                                     0
# %ACV Distribution                                   0
# Any Promo %ACV                                      0
# Disp w/o Feat %ACV                                  0
# Feat & Disp %ACV                                    0
# Feat w/o Disp %ACV                                  0
# Price Decr Only %ACV                                0
# Number of UPCs Selling                              0
# $ Shr - Ty Subcategory                          15261
# Units Shr - Ty Category                         17328
# Units Shr - Ty Subcategory                      15261
# dtype: int64

# %% [markdown]
# #### As there are only 3 types of variables, we can check that all variables are accounted for in the dataframe (notice the .T transpose)

# %%
print('Missing variables check' +' ' + str((len(integer) + len(fp) + len(segment) - len(df.T))))
# Out:
# Missing variables check 0

# %%
unique_counts = pd.DataFrame.from_records([(col, df[col].nunique()) for col in df.columns], columns=['Column_Name', 'Num_Unique']).sort_values(by=['Num_Unique'])
print(unique_counts)
# Out:
#                                      Column_Name  Num_Unique
# 0                                       ClientId           1
# 20                                           RMN           2
# 3                                      Retailers           9
# 7                                Tactic Category          18
# 6                                     CategoryId          18
# 21                                         Weeks          22
# 16                                       BrandId          46
# 17                                         Brand          46
# 8                                       VendorId          70
# 9                                         Vendor          71
# 44                        Number of UPCs Selling          77
# 19                                    StoreCount          79
# 18                             Nielsen_Week_Year          99
# 5                                         Tactic         111
# 13                  Total Tactic Redemption Cost         126
# 2                                   Program Name         256
# 1                                     Program Id         256
# 15                               Tactic End Date         256
# 26         Brand Share of Tactic Redemption Cost         262
# 29  Weekly Brand Share of Tactic Redemption Cost         263
# 14                             Tactic Start Date         265
# 41                              Feat & Disp %ACV         363
# 23                 Brand Share of Program Budget         398
# 46                       Units Shr - Ty Category         463
# 12                   Total Tactic Insertion Cost         517
# 11                            Total Tactic Spend         544
# 10                  Total Impressions for Tactic         807
# 40                            Disp w/o Feat %ACV         826
# 22                          Impressions per Week         848
# 45                        $ Shr - Ty Subcategory         920
# 47                    Units Shr - Ty Subcategory         927
# 4                                       TacticId        1057
# 42                            Feat w/o Disp %ACV        1267
# 25          Brand Share of Tactic Insertion Cost        2092
# 24             Brand Share of Total Tactic Spend        2119
# 28   Weekly Brand Share of Tactic Insertion Cost        2186
# 27      Weekly Brand Share of Total Tactic Spend        2211
# 38                             %ACV Distribution        2421
# 36                                Avg Unit Price        2478
# 43                          Price Decr Only %ACV        3073
# 39                                Any Promo %ACV        3106
# 37                               Any Promo Units        3529
# 33                                         Units        3734
# 35                                    Incr Units        3749
# 32                                        Incr $        3779
# 31                                        Base $        3807
# 34                                    Base Units        3808
# 30                                         Sales        3808

# %%
dupes = df.drop_duplicates()
print(dupes)
# Out:
#        ClientId  Program Id                                   Program Name  \
# 34            6         943        FY20 Q4 Meijer Back to School Portfolio
# 35            6         943        FY20 Q4 Meijer Back to School Portfolio
# 36            6         943        FY20 Q4 Meijer Back to School Portfolio
# 37            6         943        FY20 Q4 Meijer Back to School Portfolio
# 38            6         943        FY20 Q4 Meijer Back to School Portfolio
# ...         ...         ...                                            ...
# 20510         6        1545       FY21 Q4 Walmart Back to School Portfolio
# 20511         6         934  FY20 Q2 Walmart Jimmy Dean Frozen Masterbrand
# 20512         6         934  FY20 Q2 Walmart Jimmy Dean Frozen Masterbrand
# 20513         6         934  FY20 Q2 Walmart Jimmy Dean Frozen Masterbrand
# 20514         6         934  FY20 Q2 Walmart Jimmy Dean Frozen Masterbrand
#
#       Retailers  TacticId                                             Tactic  \
# 34       Meijer      3666                In-Store Display: Display - End Cap
# 35       Meijer      3667  Retailer-Led Tactics: Shopper Marketing Progra...
# 36       Meijer      3668      Digital Social Media: Pinterest - Equity Post
# 37       Meijer      3669                            In-Store Other: Beacons
# 38       Meijer      3670      Digital Banner Ad: Mobile Banner Ad - Dynamic
# ...         ...       ...                                                ...
# 20510   Walmart     12993  Digital Bloggers/Influencers: Influencer + Soc...
# 20511   Walmart      2241  Digital Bloggers/Influencers: Influencer + Soc...
# 20512   Walmart      2242  Digital Banner Ad: Desktop + Mobile Banner Ad ...
# 20513   Walmart      2243  Digital Text/Message: Text/Message - Push Noti...
# 20514   Walmart      2244  Digital Banner Ad: Desktop+ Mobile Banner Ad -...
#
#        CategoryId               Tactic Category  VendorId           Vendor  \
# 34             11              In-Store Display      49.0           Meijer
# 35              2          Retailer-Led Tactics      49.0           Meijer
# 36              8          Digital Social Media      94.0           Upshot
# 37             10                In-Store Other      41.0   inMarket Media
# 38              3             Digital Banner Ad      80.0         Valassis
# ...           ...                           ...       ...              ...
# 20510           4  Digital Bloggers/Influencers      94.0           Upshot
# 20511           4  Digital Bloggers/Influencers      12.0  Collective Bias
# 20512           3             Digital Banner Ad      80.0         Valassis
# 20513           9          Digital Text/Message      41.0   inMarket Media
# 20514           3             Digital Banner Ad      80.0         Valassis
#
#        ...  %ACV Distribution  Any Promo %ACV  Disp w/o Feat %ACV  \
# 34     ...              0.572           0.000               0.000
# 35     ...              0.572           0.000               0.000
# 36     ...              0.572           0.000               0.000
# 37     ...              0.572           0.000               0.000
# 38     ...              0.572           0.000               0.000
# ...    ...                ...             ...                 ...
# 20510  ...             99.400          61.600              20.400
# 20511  ...             99.445          47.762              29.834
# 20512  ...             99.445          47.762              29.834
# 20513  ...             99.445          47.762              29.834
# 20514  ...             99.445          47.762              29.834
#
#        Feat & Disp %ACV Feat w/o Disp %ACV Price Decr Only %ACV  \
# 34                  0.0                0.0                0.000
# 35                  0.0                0.0                0.000
# 36                  0.0                0.0                0.000
# 37                  0.0                0.0                0.000
# 38                  0.0                0.0                0.000
# ...                 ...                ...                  ...
# 20510               0.0                0.0               49.700
# 20511               0.0                0.0               24.482
# 20512               0.0                0.0               24.482
# 20513               0.0                0.0               24.482
# 20514               0.0                0.0               24.482
#
#        Number of UPCs Selling $ Shr - Ty Subcategory  Units Shr - Ty Category  \
# 34                        2.0                  0.002                    0.005
# 35                        2.0                  0.002                    0.005
# 36                        2.0                  0.002                    0.005
# 37                        2.0                  0.002                    0.005
# 38                        2.0                  0.002                    0.005
# ...                       ...                    ...                      ...
# 20510                    61.0                    NaN                      NaN
# 20511                    57.0                    NaN                      NaN
# 20512                    57.0                    NaN                      NaN
# 20513                    57.0                    NaN                      NaN
# 20514                    57.0                    NaN                      NaN
#
#        Units Shr - Ty Subcategory
# 34                          0.002
# 35                          0.002
# 36                          0.002
# 37                          0.002
# 38                          0.002
# ...                           ...
# 20510                         NaN
# 20511                         NaN
# 20512                         NaN
# 20513                         NaN
# 20514                         NaN
#
# [20481 rows x 48 columns]

# %%
# print(min(df_num['Sales']))
# df_num['Sales'] = pd.cut(df_num['Sales'], bins="IntervalIndex", retbins=True, right=False)
# print(min(df_num['Sales']))

# %%
df_all = df_num
Sales = df_num["Sales"].astype("float32").values
# Sales = pd.to_numeric(Sales)
num_features = df_num[['Impressions per Week','Units','%ACV Distribution','Number of UPCs Selling','Base $']]
# num_features = pd.to_numeric(num_features)

# %%
num_features = ['Impressions per Week','Units','%ACV Distribution','Number of UPCs Selling','Base $']
target = "Sales"

df_rf = df_all[num_features + [target]]

df_train, df_test = train_test_split(df_rf, test_size=0.15)

X_train, y_train, = df_train.drop('Sales',axis=1), df_train['Sales']
y_train=y_train.astype('int')
X_test, y_test = df_test.drop('Sales',axis=1), df_test['Sales']
y_test=y_test.astype('int')

rf = RandomForestClassifier(n_estimators=100, n_jobs=-1,
                            #                            max_features=X_train.shape[1]-1,
                            max_features=1.0,
                            min_samples_leaf=10, oob_score=True)
rf.fit(X_train, y_train)
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
                       max_depth=None, max_features=1.0, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, #min_impurity_split=None,
                       min_samples_leaf=10, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
                       oob_score=True, random_state=None, verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(max_features=1.0, min_samples_leaf=10, n_jobs=-1,
#                        oob_score=True)

# %%
I = importances(rf, X_test, y_test)
plot_importances(I)

# %%
# taking samples here for testing machine learning method code

# X = cortex.head(n=100)
# y = cortex.head(n=100)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,
#                                                     random_state=12)
# print(X_train.describe())
# print(y_train.describe())

# %%
# encoder = ce.OneHotEncoder(cols=['ConcatId', 'Program Name', 'Retailers',
#                                  'Tactic', 'Tactic Category', 'Vendor',
#                                  'Tactic Start Date', 'Tactic End Date',
#                                  'Brand', 'Left_Right_ConcatId',
#                                  'RMN', 'Right_ConcatId'])

# X_train = encoder.fit_transform(X_train)
# X_test = encoder.transform(X_test)
# y_train = encoder.fit_transform(y_train)
# y_test = encoder.transform(y_test)

# print(X_train.head())

# rfc = RandomForestClassifier(random_state=0)
# rfc.fit(X_train, y_train)

# %% [markdown]
# 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
